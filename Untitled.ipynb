# %% [markdown]
# # Importing Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
import statsmodels.api as sm
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder

# %matplotlib inline

# %%
data = pd.read_csv('data/kc_house_data.csv')

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# ## Data Understanding

# %%
data.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7399300360   5/24/2022 675000.00         4       1.00         1180
# 1  8910500230  12/13/2021 920000.00         5       2.50         2770
# 2  1180000275   9/29/2021 311000.00         6       2.00         2880
# 3  1604601802  12/14/2021 775000.00         3       3.00         2160
# 4  8562780790   8/24/2021 592500.00         2       2.00         1120
#
#    sqft_lot  floors waterfront greenbelt  ... sewer_system sqft_above  \
# 0      7140    1.00         NO        NO  ...       PUBLIC       1180
# 1      6703    1.00         NO        NO  ...       PUBLIC       1570
# 2      6156    1.00         NO        NO  ...       PUBLIC       1580
# 3      1400    2.00         NO        NO  ...       PUBLIC       1090
# 4       758    2.00         NO        NO  ...       PUBLIC       1120
#
#   sqft_basement sqft_garage sqft_patio yr_built  yr_renovated  \
# ...

# %%
data.shape
# Out:
# (30155, 25)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30155 entries, 0 to 30154
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             30155 non-null  int64
#  1   date           30155 non-null  object
#  2   price          30155 non-null  float64
#  3   bedrooms       30155 non-null  int64
#  4   bathrooms      30155 non-null  float64
#  5   sqft_living    30155 non-null  int64
#  6   sqft_lot       30155 non-null  int64
#  7   floors         30155 non-null  float64
#  8   waterfront     30155 non-null  object
#  9   greenbelt      30155 non-null  object
#  10  nuisance       30155 non-null  object
#  11  view           30155 non-null  object
#  12  condition      30155 non-null  object
#  13  grade          30155 non-null  object
#  14  heat_source    30123 non-null  object
#  15  sewer_system   30141 non-null  object
#  16  sqft_above     30155 non-null  int64
# ...

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  3.015500e+04  3.015500e+04  30155.000000  30155.000000  30155.000000
# mean   4.538104e+09  1.108536e+06      3.413530      2.334737   2112.424739
# std    2.882587e+09  8.963857e+05      0.981612      0.889556    974.044318
# min    1.000055e+06  2.736000e+04      0.000000      0.000000      3.000000
# 25%    2.064175e+09  6.480000e+05      3.000000      2.000000   1420.000000
# 50%    3.874011e+09  8.600000e+05      3.000000      2.500000   1920.000000
# 75%    7.287100e+09  1.300000e+06      4.000000      3.000000   2619.500000
# max    9.904000e+09  3.075000e+07     13.000000     10.500000  15360.000000
#
#            sqft_lot        floors    sqft_above  sqft_basement   sqft_garage  \
# count  3.015500e+04  30155.000000  30155.000000   30155.000000  30155.000000
# mean   1.672360e+04      1.543492   1809.826098     476.039396    330.211142
# ...

# %%
data[data.columns[1:]].corr()['price'][:].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.608521
# sqft_above       0.538651
# bathrooms        0.480401
# sqft_patio       0.313409
# bedrooms         0.289204
# sqft_garage      0.264169
# sqft_basement    0.245058
# floors           0.180576
# yr_built         0.096013
# sqft_lot         0.085730
# yr_renovated     0.084786
# lat              0.063632
# long            -0.022509
# Name: price, dtype: float64

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot()

# %%
df = data.drop(['id', 'lat', 'long', 'date', 'view', 'yr_renovated','sqft_basement', 'sqft_above'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30155 entries, 0 to 30154
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         30155 non-null  float64
#  1   bedrooms      30155 non-null  int64
#  2   bathrooms     30155 non-null  float64
#  3   sqft_living   30155 non-null  int64
#  4   sqft_lot      30155 non-null  int64
#  5   floors        30155 non-null  float64
#  6   waterfront    30155 non-null  object
#  7   greenbelt     30155 non-null  object
#  8   nuisance      30155 non-null  object
#  9   condition     30155 non-null  object
#  10  grade         30155 non-null  object
#  11  heat_source   30123 non-null  object
#  12  sewer_system  30141 non-null  object
#  13  sqft_garage   30155 non-null  int64
#  14  sqft_patio    30155 non-null  int64
#  15  yr_built      30155 non-null  int64
#  16  address       30155 non-null  object
# dtypes: float64(3), int64(6), object(8)
# ...

# %%
data['condition'].value_counts()
# Out:
# Average      18547
# Good          8054
# Very Good     3259
# Fair           230
# Poor            65
# Name: condition, dtype: int64

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Price / Bedrooms

# %%
df.sqft_living.std()
# Out:
# 974.0443184043796

# %%
df.bedrooms.value_counts()
# Out:
# 3     12754
# 4      9597
# 2      3936
# 5      2798
# 6       498
# 1       391
# 7        80
# 0        44
# 8        38
# 9        14
# 10        3
# 13        1
# 11        1
# Name: bedrooms, dtype: int64

# %%
df['bedrooms'].value_counts()

df['bedrooms_filter'] = df['bedrooms'].apply(lambda x: 1 if 2 <= x <= 4 else 0)

df['bedrooms_filter'].value_counts()

newdf = df[df['bedrooms_filter'] == 1]

# %%
newdf.bedrooms.value_counts()
# Out:
# 3    12754
# 4     9597
# 2     3936
# Name: bedrooms, dtype: int64

# %%
sns.barplot(x ='bedrooms', y ='price', data = newdf)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
sns.barplot(x ='sqft_living', y ='price', data = newdf)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
sns.stripplot(y = newdf['price'], x = newdf['bedrooms'])
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
sns.barplot(x ='floors', y ='price', data = newdf)
# Out:
# <AxesSubplot:xlabel='floors', ylabel='price'>

# %% [markdown]
# # Numeric Features

# %%
df_numeric = df.drop(['bedrooms', 'bathrooms', 'floors', 'waterfront', 'greenbelt', 'nuisance', 'grade', 'heat_source', 'sewer_system','condition'], axis=1)

# %%
df_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30155 entries, 0 to 30154
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        30155 non-null  float64
#  1   sqft_living  30155 non-null  int64
#  2   sqft_lot     30155 non-null  int64
#  3   sqft_garage  30155 non-null  int64
#  4   sqft_patio   30155 non-null  int64
#  5   yr_built     30155 non-null  int64
# dtypes: float64(1), int64(5)
# memory usage: 1.4 MB

# %% [markdown]
# ## Multiple Regression Models - Numeric

# %%
# Dropping Features with minimal correlation 
y = df_numeric['price']
MLR_X = sm.add_constant(df_numeric.drop(['price'],axis=1))
MLR = sm.OLS(y,MLR_X).fit().summary()
print(MLR)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.385
# Model:                            OLS   Adj. R-squared:                  0.385
# Method:                 Least Squares   F-statistic:                     3772.
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):               0.00
# Time:                        13:10:05   Log-Likelihood:            -4.4877e+05
# No. Observations:               30155   AIC:                         8.976e+05
# Df Residuals:                   30149   BIC:                         8.976e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        4.318e+06   2.77e+05     15.561      0.000    3.77e+06    4.86e+06
# ...

# %% [markdown]
# # Categorical Features

# %%
df_categorical = df.drop(df_numeric, axis=1)

# %%
df_categorical.head()
# Out:
#    bedrooms  bathrooms  floors waterfront greenbelt nuisance condition  \
# 0         4        1.0     1.0         NO        NO       NO      Good
# 1         5        2.5     1.0         NO        NO      YES   Average
# 2         6        2.0     1.0         NO        NO       NO   Average
# 3         3        3.0     2.0         NO        NO       NO   Average
# 4         2        2.0     2.0         NO        NO      YES   Average
#
#        grade  heat_source sewer_system
# 0  7 Average          Gas       PUBLIC
# 1  7 Average          Oil       PUBLIC
# 2  7 Average          Gas       PUBLIC
# 3   9 Better          Gas       PUBLIC
# 4  7 Average  Electricity       PUBLIC

# %%
df_categorical.bedrooms.value_counts(ascending=False)
# Out:
# 3     12754
# 4      9597
# 2      3936
# 5      2798
# 6       498
# 1       391
# 7        80
# 0        44
# 8        38
# 9        14
# 10        3
# 13        1
# 11        1
# Name: bedrooms, dtype: int64

# %%
df_categorical.bathrooms.value_counts(ascending=False)
# Out:
# 2.5     8475
# 2.0     7349
# 1.0     4576
# 3.0     4117
# 3.5     2266
# 1.5     1808
# 4.0      645
# 4.5      533
# 5.0      145
# 5.5      104
# 6.0       45
# 0.0       31
# 6.5       25
# 7.5       12
# 7.0       12
# 0.5        5
# 9.5        2
# 8.0        2
# 8.5        1
# 10.0       1
# 10.5       1
# Name: bathrooms, dtype: int64

# %%
df_categorical.floors.value_counts(ascending=False)
# Out:
# 1.0    13962
# 2.0    12265
# 1.5     2439
# 3.0     1222
# 2.5      222
# 4.0       30
# 3.5       15
# Name: floors, dtype: int64

# %%
df_categorical.waterfront.value_counts(ascending=False)
# Out:
# NO     29636
# YES      519
# Name: waterfront, dtype: int64

# %%
df_categorical.greenbelt.value_counts(ascending=False)
# Out:
# NO     29382
# YES      773
# Name: greenbelt, dtype: int64

# %%
df_categorical.nuisance.value_counts(ascending=False)
# Out:
# NO     24893
# YES     5262
# Name: nuisance, dtype: int64

# %%
df_categorical.condition.value_counts(ascending=False)
# Out:
# Average      18547
# Good          8054
# Very Good     3259
# Fair           230
# Poor            65
# Name: condition, dtype: int64

# %%
df_categorical.grade.value_counts(ascending=False)
# Out:
# 7 Average        11697
# 8 Good            9410
# 9 Better          3806
# 6 Low Average     2858
# 10 Very Good      1371
# 11 Excellent       406
# 5 Fair             393
# 12 Luxury          122
# 4 Low               51
# 13 Mansion          24
# 3 Poor              13
# 2 Substandard        2
# 1 Cabin              2
# Name: grade, dtype: int64

# %%
df_categorical.heat_source.value_counts(ascending=False)
# Out:
# Gas                  20583
# Electricity           6465
# Oil                   2899
# Gas/Solar               93
# Electricity/Solar       59
# Other                   20
# Oil/Solar                4
# Name: heat_source, dtype: int64

# %%
df_categorical.sewer_system.value_counts(ascending=False)
# Out:
# PUBLIC                25777
# PRIVATE                4355
# PRIVATE RESTRICTED        6
# PUBLIC RESTRICTED         3
# Name: sewer_system, dtype: int64

# %%
bedrooms_counts = df_categorical['bedrooms'].value_counts()

fig, ax = plt.subplots(figsize=(10,10))
ax.bar(bedrooms_counts.index, bedrooms_counts);

# %%
df_categorical.isna().sum()
# Out:
# bedrooms         0
# bathrooms        0
# floors           0
# waterfront       0
# greenbelt        0
# nuisance         0
# condition        0
# grade            0
# heat_source     32
# sewer_system    14
# dtype: int64

# %%
df_categorical = df_categorical.dropna()
df_categorical.head()
# Out:
#    bedrooms  bathrooms  floors waterfront greenbelt nuisance condition  \
# 0         4        1.0     1.0         NO        NO       NO      Good
# 1         5        2.5     1.0         NO        NO      YES   Average
# 2         6        2.0     1.0         NO        NO       NO   Average
# 3         3        3.0     2.0         NO        NO       NO   Average
# 4         2        2.0     2.0         NO        NO      YES   Average
#
#        grade  heat_source sewer_system
# 0  7 Average          Gas       PUBLIC
# 1  7 Average          Oil       PUBLIC
# 2  7 Average          Gas       PUBLIC
# 3   9 Better          Gas       PUBLIC
# 4  7 Average  Electricity       PUBLIC

# %%
df_categorical.isna().sum()
# Out:
# bedrooms        0
# bathrooms       0
# floors          0
# waterfront      0
# greenbelt       0
# nuisance        0
# condition       0
# grade           0
# heat_source     0
# sewer_system    0
# dtype: int64

# %%
sns.countplot(x ='greenbelt', data = df_categorical)
# Out:
# <AxesSubplot:xlabel='greenbelt', ylabel='count'>

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.boxplot(x ='condition', y ='bedrooms', data = df_categorical, hue ='greenbelt', width=0.8 )
# Out:
# <AxesSubplot:xlabel='condition', ylabel='bedrooms'>

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.boxplot(x ='heat_source', y ='bedrooms', data = df_categorical, hue ='greenbelt', width=1.0 )
# Out:
# <AxesSubplot:xlabel='heat_source', ylabel='bedrooms'>

# %% [markdown]
# ## Combining Dataframes

# %%
df_categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30111 entries, 0 to 30154
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   bedrooms      30111 non-null  int64
#  1   bathrooms     30111 non-null  float64
#  2   floors        30111 non-null  float64
#  3   waterfront    30111 non-null  object
#  4   greenbelt     30111 non-null  object
#  5   nuisance      30111 non-null  object
#  6   condition     30111 non-null  object
#  7   grade         30111 non-null  object
#  8   heat_source   30111 non-null  object
#  9   sewer_system  30111 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 3.8+ MB

# %%
dummy_bedrooms = pd.get_dummies(df['bedrooms'], drop_first=True)
dummy_bathrooms = pd.get_dummies(df['bathrooms'], drop_first=True)
dummy_floors = pd.get_dummies(df['floors'], drop_first=True)
dummy_condition = pd.get_dummies(df['condition'], drop_first=True)
dummy_grade = pd.get_dummies(df['grade'], drop_first=True)
dummy_heat_source = df['heat_source'].str.get_dummies(sep='/')

# %%
df.waterfront = df.waterfront.map(dict(YES=1, NO=0))
df.greenbelt = df.greenbelt.map(dict(YES=1, NO=0))
df.nuisance = df.nuisance.map(dict(YES=1, NO=0))

# %%
df_categorical.head()
# Out:
#    bedrooms  bathrooms  floors  waterfront  greenbelt  nuisance condition  \
# 0         4        1.0     1.0           0          0         0      Good
# 1         5        2.5     1.0           0          0         1   Average
# 2         6        2.0     1.0           0          0         0   Average
# 3         3        3.0     2.0           0          0         0   Average
# 4         2        2.0     2.0           0          0         1   Average
#
#        grade  heat_source sewer_system
# 0  7 Average          Gas       PUBLIC
# 1  7 Average          Oil       PUBLIC
# 2  7 Average          Gas       PUBLIC
# 3   9 Better          Gas       PUBLIC
# 4  7 Average  Electricity       PUBLIC

# %%
dummy_heat_source.head()
# Out:
#    Electricity  Gas  Oil  Other  Solar
# 0            0    1    0      0      0
# 1            0    0    1      0      0
# 2            0    1    0      0      0
# 3            0    1    0      0      0
# 4            1    0    0      0      0

# %%
cols = []
cols = list(df_numeric.columns) + list(binary_df.columns) + list(need_dummy_df.columns)

# %%
df_dummie_cat = pd.concat([need_dummy_df, binary_df], axis=1)
df_dummie_cat.head()
# Out:
#    bedrooms  bathrooms  floors condition      grade  heat_source sewer_system  \
# 0         4        1.0     1.0      Good  7 Average          Gas       PUBLIC
# 1         5        2.5     1.0   Average  7 Average          Oil       PUBLIC
# 2         6        2.0     1.0   Average  7 Average          Gas       PUBLIC
# 3         3        3.0     2.0   Average   9 Better          Gas       PUBLIC
# 4         2        2.0     2.0   Average  7 Average  Electricity       PUBLIC
#
#    greenbelt  waterfront  nuisance
# 0        NaN         NaN       NaN
# 1        NaN         NaN       NaN
# 2        NaN         NaN       NaN
# 3        NaN         NaN       NaN
# 4        NaN         NaN       NaN

# %%
df_dummie_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30155 entries, 0 to 30154
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   bedrooms      30155 non-null  int64
#  1   bathrooms     30155 non-null  float64
#  2   floors        30155 non-null  float64
#  3   condition     30155 non-null  object
#  4   grade         30155 non-null  object
#  5   heat_source   30123 non-null  object
#  6   sewer_system  30141 non-null  object
#  7   greenbelt     0 non-null      float64
#  8   waterfront    0 non-null      float64
#  9   nuisance      0 non-null      float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 2.3+ MB

# %%
df_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30155 entries, 0 to 30154
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        30155 non-null  float64
#  1   sqft_living  30155 non-null  int64
#  2   sqft_lot     30155 non-null  int64
#  3   sqft_garage  30155 non-null  int64
#  4   sqft_patio   30155 non-null  int64
#  5   yr_built     30155 non-null  int64
# dtypes: float64(1), int64(5)
# memory usage: 1.4 MB

# %%
all_cat = pd.concat([df_numeric, df_dummie_cat], axis=1)
all_cat.head()
# Out:
#       price  sqft_living  sqft_lot  sqft_garage  sqft_patio  yr_built  \
# 0  675000.0         1180      7140            0          40      1969
# 1  920000.0         2770      6703            0         240      1950
# 2  311000.0         2880      6156            0           0      1956
# 3  775000.0         2160      1400          200         270      2010
# 4  592500.0         1120       758          550          30      2012
#
#    bedrooms  bathrooms  floors condition      grade  heat_source sewer_system  \
# 0         4        1.0     1.0      Good  7 Average          Gas       PUBLIC
# 1         5        2.5     1.0   Average  7 Average          Oil       PUBLIC
# 2         6        2.0     1.0   Average  7 Average          Gas       PUBLIC
# 3         3        3.0     2.0   Average   9 Better          Gas       PUBLIC
# 4         2        2.0     2.0   Average  7 Average  Electricity       PUBLIC
#
#    greenbelt  waterfront  nuisance
# 0        NaN         NaN       NaN
# ...

# %%
y = all_cat['price']
X_c = sm.add_constant(all_cat.drop(['price'], axis=1))
model = sm.OLS(y,X_c).fit()
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-0d4baac4a992> in <module>
#       1 y = all_cat['price']
#       2 X_c = sm.add_constant(all_cat.drop(['price'], axis=1))
# ----> 3 model = sm.OLS(y,X_c).fit()
#       4 model.summary()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     870     def __init__(self, endog, exog=None, missing='none', hasconst=None,
#     871                  **kwargs):
# --> 872         super(OLS, self).__init__(endog, exog, missing=missing,
#     873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#
# ...

# %%
y = all_cat['price']
X_c1 = sm.add_constant(all_cat.drop(['price', 'sqft_lot', 'sqft_garage', 'greenbelt', 'bathrooms'], axis=1))
model2 = sm.OLS(y,X_c1).fit()
model2.summary()
